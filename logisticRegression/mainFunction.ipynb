# %%
import matplotlib.pyplot as plt
from numpy import *
import ipynbImporter
from imp import reload
import logRegres
# reload(logRegres)
dataMat, labelMat = logRegres.loadDataSet('testSet.txt')
#weights = logRegres.gradAscent(dataArr, labelArr, 0.001, 500)

# %%
dataMat, labelMat = logRegres.loadDataSet('testSet.txt')
#weights = logRegres.gradAscent(dataArr, labelArr, 0.001, 500)

# %%
# reload(logRegres)
logRegres.plotBestFit(weights)

# %%
# reload(logRegres)
weights = logRegres.stocGradAscent0(array(dataMat), labelMat, 0.01)
print(weights)
logRegres.plotBestFit(weights)
# Out:
# [ 1.01702007  0.85914348 -0.36579921]

# %%
# reload(logRegres)
weights = logRegres.stocGradAscent1(array(dataMat), labelMat)
logRegres.plotBestFit(weights)

# %% [markdown]
# # 为什么错误率这么高？？？？？？？？？？？？？？？？？

# %%
# reload(logRegres)
logRegres.colicTest('horseColicTraining.txt', 'horseColicTest.txt')
logRegres.multiTest('horseColicTraining.txt', 'horseColicTest.txt')    #为什么错误率这么高？？？？？？？？？？？？？？？？？
# Out:
# importing Jupyter notebook from logRegres.ipynb
# the error rate of this test is: 0.686567
# the error rate of this test is: 0.671642
# the error rate of this test is: 0.641791
# the error rate of this test is: 0.626866
# the error rate of this test is: 0.701493
# the error rate of this test is: 0.641791
# the error rate of this test is: 0.716418
# the error rate of this test is: 0.611940
# the error rate of this test is: 0.626866
# the error rate of this test is: 0.611940
# the error rate of this test is: 0.686567
# after 10 iterations the average error rate is: 0.653731
